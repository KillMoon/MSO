# %% [markdown]
# Practice 2

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
data = pd.read_excel('practice_dataframe.xlsx', usecols=['cat5_customerSatisfaction', 'cat1_gender', 'num1_10', 'num2_10', 'num3_10'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
# cat1_gender                  982 non-null object
# cat5_customerSatisfaction    981 non-null object
# num1_10                      1000 non-null float64
# num2_10                      952 non-null float64
# num3_10                      970 non-null object
# dtypes: float64(2), object(3)
# memory usage: 27.4+ KB

# %%
data.head()
# Out:
#   cat1_gender cat5_customerSatisfaction      num1_10    num2_10  num3_10
# 0        male                      good  1952.951114 -14.984191
# 1        male                      Good   248.952820  15.251861  624.089
# 2        male                      Good   465.578792  72.069553        -
# 3         NaN                 Very good   746.798307 -61.282697  702.582
# 4        male                 Very good   -92.649660  11.401243  738.488

# %% [markdown]
# Задание №1

# %%
plt.figure(figsize=(10, 10))
data['cat1_gender'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='cat1_gender'>

# %%
data['cat5_customerSatisfaction'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15, 10))
data['num1_10'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.displot(data=data, x='num1_10', kde=True);
sns.displot(data=data, x='num2_10', kde=True);

# %%
sns.catplot(data=data,
            x='cat5_customerSatisfaction',
            y='num1_10',
            kind='box');

# %% [markdown]
# Задание № 2

# %%
data['cat1_gender'] = data['cat1_gender'].replace(('-',' '), np.nan).replace('male', 'Male').replace('female', 'Female')

# %%
plt.figure(figsize=(10, 10))
data['cat1_gender'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='cat1_gender'>

# %%
data['cat5_customerSatisfaction'].unique()
# Out:
# array(['good', 'Good', 'Very good', 'Neutral', '-', 'Very poor', 'poor',
#        'Poor', ' ', nan], dtype=object)

# %%
data['cat5_customerSatisfaction'].replace('good', 'Good', True).replace('poor', 'Poor', True).replace(('-', 'nan', ' '), np.nan, True)
plt.figure(figsize=(10, 10))
data['cat5_customerSatisfaction'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-8787c908a6f3> in <module>
# ----> 1 data['cat5_customerSatisfaction'] = data['cat5_customerSatisfaction'].replace('good', 'Good', True).replace('poor', 'Poor', True).replace(('-', 'nan', ' '), np.nan, True)
#       2 plt.figure(figsize=(10, 10))
#       3 data['cat5_customerSatisfaction'].value_counts().plot.pie(autopct='%1.1f%%')
#
# AttributeError: 'NoneType' object has no attribute 'replace'

# %% [markdown]
# Задание №3

# %%
from scipy.stats import sigmaclip

c, low, upp = sigmaclip(data['num1_10'], 4.0, 4.0)
sns.displot(data=c,
            bins=30,
            kde=True);

# %% [markdown]
# Задание №4

# %%
from sklearn.impute import KNNImputer

# d = KNNImputer()
# d.fit_transform(data['cat5_customerSatisfaction'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-907ebad763be> in <module>
#       2
#       3 d = KNNImputer()
# ----> 4 d.fit_transform(data['cat5_customerSatisfaction'])
#
# c:\users\killm\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# c:\users\killm\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\impute\_knn.py in fit(self, X, y)
#     182                 "Expected n_neighbors > 0. Got {}".format(self.n_neighbors))
#     183
# --> 184         X = self._validate_data(X, accept_sparse=False, dtype=FLOAT_DTYPES,
#     185                                 force_all_finite=force_all_finite,
#     186                                 copy=self.copy)
#
# c:\users\killm\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# c:\users\killm\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# c:\users\killm\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     596                     array = array.astype(dtype, casting="unsafe", copy=False)
#     597                 else:
# --> 598                     array = np.asarray(array, order=order, dtype=dtype)
#     599             except ComplexWarning:
#     600                 raise ValueError("Complex data not supported\n"
#
# c:\users\killm\appdata\local\programs\python\python38-32\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# c:\users\killm\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\series.py in __array__(self, dtype)
#     949             warnings.warn(msg, FutureWarning, stacklevel=3)
#     950             dtype = "M8[ns]"
# --> 951         return np.asarray(self.array, dtype)
#     952
#     953     # ----------------------------------------------------------------------
#
# c:\users\killm\appdata\local\programs\python\python38-32\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# c:\users\killm\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\arrays\numpy_.py in __array__(self, dtype)
#     164
#     165     def __array__(self, dtype=None):
# --> 166         return np.asarray(self._ndarray, dtype=dtype)
#     167
#     168     _HANDLED_TYPES = (np.ndarray, numbers.Number)
#
# c:\users\killm\appdata\local\programs\python\python38-32\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'Good'

# %%
gender_mode = data.cat1_gender.mode()
data.cat1_gender.fillna(gender_mode[0])
data.cat1_gender.isnull().any()
# Out:
# False

# %%
data.num2_10.median()
# Out:
# -1.6018296347897505
